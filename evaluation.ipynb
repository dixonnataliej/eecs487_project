# %%
#import

import json
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#read jsons

language_strings = ["malay", "nahuatl", "quechua", "wolof"] #Tibetan removed due to formatting errors
language_jsons = {}
for language_string in language_strings:
    language_json_string =  language_string + ".json"

    with open(language_json_string, 'r', encoding='utf-8') as fp:
        language_json = json.load(fp)
        language_jsons[language_string] = language_json

# %%
#evaluation

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.translate import bleu_score
from nltk.translate.meteor_score import meteor_score
from nltk.translate.bleu_score import SmoothingFunction
from collections import defaultdict

bleu_score_chat = defaultdict(lambda:0.0)
bleu_score_google = defaultdict(lambda:0.0)
meteor_score_chat = defaultdict(lambda:0.0)
meteor_score_google = defaultdict(lambda:0.0)

for language_string, language_json in language_jsons.items():

  print("\n" + language_string + "\n")

  for passage_number in language_json['passages']:

    if passage_number == "5" or passage_number == "6":  #5 and 6 does not have official translation
      continue

    passage = language_json['passages'][passage_number]

    official = passage['official']
    chatgpt = passage['chatgpt']
    google = passage['google']

    sent_token = sent_tokenize(official)

    chat_token = sent_tokenize(chatgpt)

    google_token = sent_tokenize(google)

    sent_tokenized = []
    for sent in sent_token:
      tokens = word_tokenize(sent)
      sent_tokenized.append(tokens)

    chat_tokenized = []
    for sent in chat_token:
      tokens = word_tokenize(sent)
      chat_tokenized.append(tokens)

    google_tokenized = []
    for sent in google_token:
      tokens = word_tokenize(sent)
      google_tokenized.append(tokens)

    """
    BLEU score

    All hypothesis (translated sentences) have the official translation as references. Due to us not knowing which sentence
    in the official translation translates to which sentence in the translated sentences (as we translated per paragraph
    instead of per sentence), we decided to account for all the sentences in the official to simplify our program

    We used corpus_blue() to calculate the BLEU score
    Per https://www.nltk.org/api/nltk.translate.bleu_score.html:
    Calculate a single corpus-level BLEU score (aka. system-level BLEU) for all the hypotheses and their respective references.
    Instead of averaging the sentence level BLEU scores (i.e. macro-average precision), the original BLEU metric
    (Papineni et al. 2002) accounts for the micro-average precision (i.e. summing the numerators and denominators for each
    hypothesis-reference(s) pairs before the division).

    """

    references = []

    sent_list = [sent for sent in sent_tokenized]

    for _ in range(len(chat_tokenized)):
      references.append(sent_list)

    chat_score_bleu = bleu_score.corpus_bleu(references, chat_tokenized, smoothing_function=SmoothingFunction().method2)
    print(f"ChatGPT BLEU score for passage {passage_number} for language {language_string}:", chat_score_bleu)
    bleu_score_chat[language_string] += chat_score_bleu

    references = []

    sent_list = [sent for sent in sent_tokenized]

    for _ in range(len(google_tokenized)):
      references.append(sent_list)

    google_score_bleu = bleu_score.corpus_bleu(references, google_tokenized, smoothing_function=SmoothingFunction().method2)
    print(f"Google Translate BLEU score for passage {passage_number} for language {language_string}:", google_score_bleu)
    bleu_score_google[language_string] += google_score_bleu

    print("\n")

    """
    METEOR score

    Same as BLEU, we use all the official translation as the references for every translated sentence in the paragraph.

    Instead of able to calculate multiple sentences at once, we have to evaluate every sentence in the
    translated paragraph and average it to get the METEOR score

    We used meteor_score() to calculate the BLEU score
    Per https://www.nltk.org/api/nltk.translate.meteor_score.html:
    Calculates METEOR score for hypothesis with multiple references as described in
    “Meteor: An Automatic Metric for MT Evaluation with HighLevels of Correlation with Human Judgments” by Alon Lavie and Abhaya Agarwal,
    in Proceedings of ACL. https://www.cs.cmu.edu/~alavie/METEOR/pdf/Lavie-Agarwal-2007-METEOR.pdf
    In case of multiple references the best score is chosen. This method iterates over single_meteor_score and
    picks the best pair among all the references for a given hypothesis

    """

    avg_chat_meteor = 0.0
    avg_google_meteor = 0.0

    for i,sent in enumerate(chat_tokenized):
      chat_meteor_score = meteor_score(sent_list, sent)
      avg_chat_meteor += chat_meteor_score
      print(f"ChatGPT METEOR score for passage {passage_number} sentence {i+1} for {language_string} language:", chat_meteor_score)

    for i,sent in enumerate(google_tokenized):
      google_meteor_score = meteor_score(sent_list, sent)
      avg_google_meteor += google_meteor_score
      print(f"Google Translate METEOR score for passage {passage_number} sentence {i+1} for {language_string} language:", google_meteor_score)

    print("\n")

    print(f"Averaged ChatGPT METEOR score for passage {passage_number} for {language_string} language:", avg_chat_meteor/len(chat_token))
    print(f"Averaged Google Translate METEOR score for passage {passage_number} for {language_string} language:", avg_google_meteor/len(google_token))
    meteor_score_chat[language_string] += avg_chat_meteor/len(chat_token)
    meteor_score_google[language_string] += avg_google_meteor/len(google_token)

    print("\n")

for language_string in language_strings:
  print(f"Averaged ChatGPT BLEU score for language {language_string}:", bleu_score_chat[language_string]/4)
  print(f"Averaged Google Translate BLEU score for language {language_string}:", bleu_score_google[language_string]/4)
  print(f"Averaged ChatGPT METEOR score for language {language_string}:", meteor_score_chat[language_string]/4)
  print(f"Averaged Google Translate METEOR score for language {language_string}:", meteor_score_google[language_string]/4)
  print("\n")
# Out:
# malay
#
# ChatGPT BLEU score for passage 1 for language malay: 0.04444176295633874
# Google Translate BLEU score for passage 1 for language malay: 0.04422615079668136
#
#
# ChatGPT METEOR score for passage 1 sentence 1 for malay language: 0.1293103448275862
# ChatGPT METEOR score for passage 1 sentence 2 for malay language: 0.0819672131147541
# ChatGPT METEOR score for passage 1 sentence 3 for malay language: 0.4179775280898876
# ChatGPT METEOR score for passage 1 sentence 4 for malay language: 0.2937420178799489
# ChatGPT METEOR score for passage 1 sentence 5 for malay language: 0.1149425287356322
# ChatGPT METEOR score for passage 1 sentence 6 for malay language: 0.11904761904761905
# ChatGPT METEOR score for passage 1 sentence 7 for malay language: 0.38490853658536583
# Google Translate METEOR score for passage 1 sentence 1 for malay language: 0.1293103448275862
# Google Translate METEOR score for passage 1 sentence 2 for malay language: 0.08130081300813008
# Google Translate METEOR score for passage 1 sentence 3 for malay language: 0.41333333333333333
# Google Translate METEOR score for passage 1 sentence 4 for malay language: 0.13761467889908252
# Google Translate METEOR score for passage 1 sentence 5 for malay language: 0.13157894736842105
# Google Translate METEOR score for passage 1 sentence 6 for malay language: 0.13392857142857142
# Google Translate METEOR score for passage 1 sentence 7 for malay language: 0.3194444444444444
#
#
# Averaged ChatGPT METEOR score for passage 1 for malay language: 0.22027082689725624
# Averaged Google Translate METEOR score for passage 1 for malay language: 0.19235873332993841
#
#
# ChatGPT BLEU score for passage 2 for language malay: 0.31344956258359996
# Google Translate BLEU score for passage 2 for language malay: 0.199105476936112
#
#
# ChatGPT METEOR score for passage 2 sentence 1 for malay language: 0.7052154195011338
# ChatGPT METEOR score for passage 2 sentence 2 for malay language: 0.8652871086322728
# ChatGPT METEOR score for passage 2 sentence 3 for malay language: 0.46922047507527603
# ChatGPT METEOR score for passage 2 sentence 4 for malay language: 0.4864491668226924
# ChatGPT METEOR score for passage 2 sentence 5 for malay language: 0.28055555555555556
# ChatGPT METEOR score for passage 2 sentence 6 for malay language: 0.21621621621621617
# Google Translate METEOR score for passage 2 sentence 1 for malay language: 0.41333333333333333
# Google Translate METEOR score for passage 2 sentence 2 for malay language: 0.854119425547997
# Google Translate METEOR score for passage 2 sentence 3 for malay language: 0.4224058769513315
# Google Translate METEOR score for passage 2 sentence 4 for malay language: 0.5673040244135037
# Google Translate METEOR score for passage 2 sentence 5 for malay language: 0.2793141592920354
# Google Translate METEOR score for passage 2 sentence 6 for malay language: 0.19125683060109291
#
#
# Averaged ChatGPT METEOR score for passage 2 for malay language: 0.5038239903005245
# Averaged Google Translate METEOR score for passage 2 for malay language: 0.4546222750232156
#
#
# ChatGPT BLEU score for passage 3 for language malay: 0.11243162047223815
# Google Translate BLEU score for passage 3 for language malay: 0.10790478898155687
#
#
# ChatGPT METEOR score for passage 3 sentence 1 for malay language: 0.19669760509967682
# ChatGPT METEOR score for passage 3 sentence 2 for malay language: 0.2495515458478422
# Google Translate METEOR score for passage 3 sentence 1 for malay language: 0.19669760509967682
# Google Translate METEOR score for passage 3 sentence 2 for malay language: 0.2425631269456935
#
#
# Averaged ChatGPT METEOR score for passage 3 for malay language: 0.22312457547375952
# Averaged Google Translate METEOR score for passage 3 for malay language: 0.21963036602268515
#
#
# ChatGPT BLEU score for passage 4 for language malay: 0.5540826937742469
# Google Translate BLEU score for passage 4 for language malay: 0.6473403627036354
#
#
# ChatGPT METEOR score for passage 4 sentence 1 for malay language: 0.8084415584415583
# ChatGPT METEOR score for passage 4 sentence 2 for malay language: 0.8719765684051398
# Google Translate METEOR score for passage 4 sentence 1 for malay language: 0.8453636065763352
# Google Translate METEOR score for passage 4 sentence 2 for malay language: 0.9493586839350717
#
#
# Averaged ChatGPT METEOR score for passage 4 for malay language: 0.840209063423349
# Averaged Google Translate METEOR score for passage 4 for malay language: 0.8973611452557035
#
#
#
# nahuatl
#
# ChatGPT BLEU score for passage 1 for language nahuatl: 0.035612268246077196
# Google Translate BLEU score for passage 1 for language nahuatl: 0.4141051044473926
#
#
# ChatGPT METEOR score for passage 1 sentence 1 for nahuatl language: 0.136986301369863
# ChatGPT METEOR score for passage 1 sentence 2 for nahuatl language: 0.1492537313432836
# ChatGPT METEOR score for passage 1 sentence 3 for nahuatl language: 0.15625000000000003
# ChatGPT METEOR score for passage 1 sentence 4 for nahuatl language: 0.22058823529411764
# ChatGPT METEOR score for passage 1 sentence 5 for nahuatl language: 0.14814814814814817
# ChatGPT METEOR score for passage 1 sentence 6 for nahuatl language: 0.15151515151515152
# ChatGPT METEOR score for passage 1 sentence 7 for nahuatl language: 0.23148148148148148
# Google Translate METEOR score for passage 1 sentence 1 for nahuatl language: 0.4383680555555556
# Google Translate METEOR score for passage 1 sentence 2 for nahuatl language: 0.20833333333333331
# Google Translate METEOR score for passage 1 sentence 3 for nahuatl language: 0.2
# Google Translate METEOR score for passage 1 sentence 4 for nahuatl language: 0.8534621578099838
# Google Translate METEOR score for passage 1 sentence 5 for nahuatl language: 0.7019054178145087
# Google Translate METEOR score for passage 1 sentence 6 for nahuatl language: 0.8788235294117647
# Google Translate METEOR score for passage 1 sentence 7 for nahuatl language: 0.9985422740524781
#
#
# Averaged ChatGPT METEOR score for passage 1 for nahuatl language: 0.17060329273600647
# Averaged Google Translate METEOR score for passage 1 for nahuatl language: 0.6113478239968035
#
#
# ChatGPT BLEU score for passage 2 for language nahuatl: 0.023808559802646543
# Google Translate BLEU score for passage 2 for language nahuatl: 0.13581026240994437
#
#
# ChatGPT METEOR score for passage 2 sentence 1 for nahuatl language: 0.11627906976744187
# ChatGPT METEOR score for passage 2 sentence 2 for nahuatl language: 0.11627906976744187
# ChatGPT METEOR score for passage 2 sentence 3 for nahuatl language: 0.11363636363636363
# ChatGPT METEOR score for passage 2 sentence 4 for nahuatl language: 0.10526315789473684
# ChatGPT METEOR score for passage 2 sentence 5 for nahuatl language: 0.12269938650306748
# ChatGPT METEOR score for passage 2 sentence 6 for nahuatl language: 0.13043478260869565
# Google Translate METEOR score for passage 2 sentence 1 for nahuatl language: 0.125
# Google Translate METEOR score for passage 2 sentence 2 for nahuatl language: 0.4406130268199233
# Google Translate METEOR score for passage 2 sentence 3 for nahuatl language: 0.4955555555555556
# Google Translate METEOR score for passage 2 sentence 4 for nahuatl language: 0.4042636162745352
# Google Translate METEOR score for passage 2 sentence 5 for nahuatl language: 0.607682915375223
# Google Translate METEOR score for passage 2 sentence 6 for nahuatl language: 0.1694915254237288
# Google Translate METEOR score for passage 2 sentence 7 for nahuatl language: 0.25974025974025977
# Google Translate METEOR score for passage 2 sentence 8 for nahuatl language: 0.125
# Google Translate METEOR score for passage 2 sentence 9 for nahuatl language: 0.3878260869565217
#
#
# Averaged ChatGPT METEOR score for passage 2 for nahuatl language: 0.11743197169629123
# Averaged Google Translate METEOR score for passage 2 for nahuatl language: 0.3350192206828608
#
#
# ChatGPT BLEU score for passage 3 for language nahuatl: 0.042559045115907225
# Google Translate BLEU score for passage 3 for language nahuatl: 0.23853727239085795
#
#
# ChatGPT METEOR score for passage 3 sentence 1 for nahuatl language: 0.21108360836083606
# ChatGPT METEOR score for passage 3 sentence 2 for nahuatl language: 0.2032786885245902
# Google Translate METEOR score for passage 3 sentence 1 for nahuatl language: 0.6023943865740741
# Google Translate METEOR score for passage 3 sentence 2 for nahuatl language: 0.5569306930693068
# Google Translate METEOR score for passage 3 sentence 3 for nahuatl language: 0.21276595744680854
#
#
# Averaged ChatGPT METEOR score for passage 3 for nahuatl language: 0.20718114844271313
# Averaged Google Translate METEOR score for passage 3 for nahuatl language: 0.4573636790300631
#
#
# ChatGPT BLEU score for passage 4 for language nahuatl: 0.0739615923411127
# Google Translate BLEU score for passage 4 for language nahuatl: 0.0519220348247666
#
#
# ChatGPT METEOR score for passage 4 sentence 1 for nahuatl language: 0.11961722488038276
# Google Translate METEOR score for passage 4 sentence 1 for nahuatl language: 0.09216589861751152
#
#
# Averaged ChatGPT METEOR score for passage 4 for nahuatl language: 0.11961722488038276
# Averaged Google Translate METEOR score for passage 4 for nahuatl language: 0.09216589861751152
#
#
#
# quechua
#
# ChatGPT BLEU score for passage 1 for language quechua: 0.04696574269250718
# Google Translate BLEU score for passage 1 for language quechua: 0.06089903678922838
#
#
# ChatGPT METEOR score for passage 1 sentence 1 for quechua language: 0.13888888888888887
# ChatGPT METEOR score for passage 1 sentence 2 for quechua language: 0.3409090909090909
# ChatGPT METEOR score for passage 1 sentence 3 for quechua language: 0.189873417721519
# ChatGPT METEOR score for passage 1 sentence 4 for quechua language: 0.3599374021909233
# ChatGPT METEOR score for passage 1 sentence 5 for quechua language: 0.46875
# ChatGPT METEOR score for passage 1 sentence 6 for quechua language: 0.1744186046511628
# ChatGPT METEOR score for passage 1 sentence 7 for quechua language: 0.10204081632653061
# ChatGPT METEOR score for passage 1 sentence 8 for quechua language: 0.398936170212766
# Google Translate METEOR score for passage 1 sentence 1 for quechua language: 0.2388369678089304
# Google Translate METEOR score for passage 1 sentence 2 for quechua language: 0.4076086956521739
# Google Translate METEOR score for passage 1 sentence 3 for quechua language: 0.12195121951219512
# Google Translate METEOR score for passage 1 sentence 4 for quechua language: 0.12658227848101264
# Google Translate METEOR score for passage 1 sentence 5 for quechua language: 0.2533783783783784
# Google Translate METEOR score for passage 1 sentence 6 for quechua language: 0.10204081632653061
# Google Translate METEOR score for passage 1 sentence 7 for quechua language: 0.10638297872340427
# Google Translate METEOR score for passage 1 sentence 8 for quechua language: 0.44642857142857145
#
#
# Averaged ChatGPT METEOR score for passage 1 for quechua language: 0.2717192988626102
# Averaged Google Translate METEOR score for passage 1 for quechua language: 0.22540123828889957
#
#
# ChatGPT BLEU score for passage 2 for language quechua: 0.026280792312775098
# Google Translate BLEU score for passage 2 for language quechua: 0.029921717206534134
#
#
# ChatGPT METEOR score for passage 2 sentence 1 for quechua language: 0.21739130434782608
# ChatGPT METEOR score for passage 2 sentence 2 for quechua language: 0.12195121951219512
# ChatGPT METEOR score for passage 2 sentence 3 for quechua language: 0.125
# ChatGPT METEOR score for passage 2 sentence 4 for quechua language: 0.11904761904761905
# ChatGPT METEOR score for passage 2 sentence 5 for quechua language: 0.10309278350515463
# ChatGPT METEOR score for passage 2 sentence 6 for quechua language: 0.11904761904761905
# ChatGPT METEOR score for passage 2 sentence 7 for quechua language: 0.12195121951219512
# ChatGPT METEOR score for passage 2 sentence 8 for quechua language: 0.12048192771084339
# ChatGPT METEOR score for passage 2 sentence 9 for quechua language: 0.12195121951219512
# Google Translate METEOR score for passage 2 sentence 1 for quechua language: 0.23255813953488375
# Google Translate METEOR score for passage 2 sentence 2 for quechua language: 0.12195121951219512
# Google Translate METEOR score for passage 2 sentence 3 for quechua language: 0.11111111111111112
# Google Translate METEOR score for passage 2 sentence 4 for quechua language: 0.11235955056179776
# Google Translate METEOR score for passage 2 sentence 5 for quechua language: 0.125
# Google Translate METEOR score for passage 2 sentence 6 for quechua language: 0.10869565217391304
# Google Translate METEOR score for passage 2 sentence 7 for quechua language: 0.12820512820512822
# Google Translate METEOR score for passage 2 sentence 8 for quechua language: 0.1149425287356322
#
#
# Averaged ChatGPT METEOR score for passage 2 for quechua language: 0.12999054579951638
# Averaged Google Translate METEOR score for passage 2 for quechua language: 0.13185291622933265
#
#
# ChatGPT BLEU score for passage 3 for language quechua: 0.04644898923832784
# Google Translate BLEU score for passage 3 for language quechua: 0.04027061502545063
#
#
# ChatGPT METEOR score for passage 3 sentence 1 for quechua language: 0.1079136690647482
# ChatGPT METEOR score for passage 3 sentence 2 for quechua language: 0.11450381679389314
# Google Translate METEOR score for passage 3 sentence 1 for quechua language: 0.07194244604316548
# Google Translate METEOR score for passage 3 sentence 2 for quechua language: 0.06097560975609756
# Google Translate METEOR score for passage 3 sentence 3 for quechua language: 0.06329113924050632
#
#
# Averaged ChatGPT METEOR score for passage 3 for quechua language: 0.11120874292932068
# Averaged Google Translate METEOR score for passage 3 for quechua language: 0.06540306501325645
#
#
# ChatGPT BLEU score for passage 4 for language quechua: 0.05823647652590255
# Google Translate BLEU score for passage 4 for language quechua: 0.07583235673413397
#
#
# ChatGPT METEOR score for passage 4 sentence 1 for quechua language: 0.12096774193548386
# ChatGPT METEOR score for passage 4 sentence 2 for quechua language: 0.08333333333333333
# Google Translate METEOR score for passage 4 sentence 1 for quechua language: 0.10989010989010987
# Google Translate METEOR score for passage 4 sentence 2 for quechua language: 0.08403361344537816
#
#
# Averaged ChatGPT METEOR score for passage 4 for quechua language: 0.1021505376344086
# Averaged Google Translate METEOR score for passage 4 for quechua language: 0.09696186166774401
#
#
#
# wolof
#
# ChatGPT BLEU score for passage 1 for language wolof: 0.12985099581200685
# Google Translate BLEU score for passage 1 for language wolof: 0.5912723140736851
#
#
# ChatGPT METEOR score for passage 1 sentence 1 for wolof language: 0.5888888888888889
# ChatGPT METEOR score for passage 1 sentence 2 for wolof language: 0.13513513513513511
# ChatGPT METEOR score for passage 1 sentence 3 for wolof language: 0.10000000000000002
# ChatGPT METEOR score for passage 1 sentence 4 for wolof language: 0.15
# ChatGPT METEOR score for passage 1 sentence 5 for wolof language: 0.10638297872340426
# ChatGPT METEOR score for passage 1 sentence 6 for wolof language: 0.6388429752066117
# ChatGPT METEOR score for passage 1 sentence 7 for wolof language: 0.28846153846153844
# ChatGPT METEOR score for passage 1 sentence 8 for wolof language: 0.34128440366972473
# Google Translate METEOR score for passage 1 sentence 1 for wolof language: 0.9995
# Google Translate METEOR score for passage 1 sentence 2 for wolof language: 0.19230769230769232
# Google Translate METEOR score for passage 1 sentence 3 for wolof language: 0.09900990099009903
# Google Translate METEOR score for passage 1 sentence 4 for wolof language: 0.9422781271837876
# Google Translate METEOR score for passage 1 sentence 5 for wolof language: 0.9995
# Google Translate METEOR score for passage 1 sentence 6 for wolof language: 0.9671655126200581
#
#
# Averaged ChatGPT METEOR score for passage 1 for wolof language: 0.2936244900106629
# Averaged Google Translate METEOR score for passage 1 for wolof language: 0.6999602055169395
#
#
# ChatGPT BLEU score for passage 2 for language wolof: 0.04417344563361231
# Google Translate BLEU score for passage 2 for language wolof: 0.05798587778960909
#
#
# ChatGPT METEOR score for passage 2 sentence 1 for wolof language: 0.08403361344537816
# ChatGPT METEOR score for passage 2 sentence 2 for wolof language: 0.17762660619803478
# ChatGPT METEOR score for passage 2 sentence 3 for wolof language: 0.21440036688832834
# ChatGPT METEOR score for passage 2 sentence 4 for wolof language: 0.25392491467576794
# ChatGPT METEOR score for passage 2 sentence 5 for wolof language: 0.09950248756218907
# ChatGPT METEOR score for passage 2 sentence 6 for wolof language: 0.0847457627118644
# ChatGPT METEOR score for passage 2 sentence 7 for wolof language: 0.22639593908629446
# Google Translate METEOR score for passage 2 sentence 1 for wolof language: 0.2652310924369748
# Google Translate METEOR score for passage 2 sentence 2 for wolof language: 0.19778113382899626
# Google Translate METEOR score for passage 2 sentence 3 for wolof language: 0.21440036688832834
# Google Translate METEOR score for passage 2 sentence 4 for wolof language: 0.18799690812720848
# Google Translate METEOR score for passage 2 sentence 5 for wolof language: 0.13726937269372697
# Google Translate METEOR score for passage 2 sentence 6 for wolof language: 0.14150943396226415
# Google Translate METEOR score for passage 2 sentence 7 for wolof language: 0.34598214285714285
#
#
# Averaged ChatGPT METEOR score for passage 2 for wolof language: 0.162947098652551
# Averaged Google Translate METEOR score for passage 2 for wolof language: 0.2128814929706631
#
#
# ChatGPT BLEU score for passage 3 for language wolof: 0.2528078903242922
# Google Translate BLEU score for passage 3 for language wolof: 0.7520326770058819
#
#
# ChatGPT METEOR score for passage 3 sentence 1 for wolof language: 0.6388429752066117
# ChatGPT METEOR score for passage 3 sentence 2 for wolof language: 0.5540372670807454
# Google Translate METEOR score for passage 3 sentence 1 for wolof language: 0.9999814814814815
# Google Translate METEOR score for passage 3 sentence 2 for wolof language: 0.6777108433734939
#
#
# Averaged ChatGPT METEOR score for passage 3 for wolof language: 0.5964401211436785
# Averaged Google Translate METEOR score for passage 3 for wolof language: 0.8388461624274877
#
#
# ChatGPT BLEU score for passage 4 for language wolof: 0.06180255917500315
# Google Translate BLEU score for passage 4 for language wolof: 0.08934210024279061
#
#
# ChatGPT METEOR score for passage 4 sentence 1 for wolof language: 0.39421979972113064
# ChatGPT METEOR score for passage 4 sentence 2 for wolof language: 0.2551020408163265
# ChatGPT METEOR score for passage 4 sentence 3 for wolof language: 0.34773284313725494
# ChatGPT METEOR score for passage 4 sentence 4 for wolof language: 0.189873417721519
# ChatGPT METEOR score for passage 4 sentence 5 for wolof language: 0.13513513513513514
# Google Translate METEOR score for passage 4 sentence 1 for wolof language: 0.231055900621118
# Google Translate METEOR score for passage 4 sentence 2 for wolof language: 0.3075862068965517
# Google Translate METEOR score for passage 4 sentence 3 for wolof language: 0.4231292517006803
# Google Translate METEOR score for passage 4 sentence 4 for wolof language: 0.2408976773383553
# Google Translate METEOR score for passage 4 sentence 5 for wolof language: 0.10135135135135134
#
#
# Averaged ChatGPT METEOR score for passage 4 for wolof language: 0.26441264730627323
# Averaged Google Translate METEOR score for passage 4 for wolof language: 0.2608040775816113
#
#
# Averaged ChatGPT BLEU score for language malay: 0.2561014099466059
# Averaged Google Translate BLEU score for language malay: 0.2496441948544964
# Averaged ChatGPT METEOR score for language malay: 0.4468571140237223
# Averaged Google Translate METEOR score for language malay: 0.44099312990788564
#
#
# Averaged ChatGPT BLEU score for language nahuatl: 0.04398536637643592
# Averaged Google Translate BLEU score for language nahuatl: 0.2100936685182404
# Averaged ChatGPT METEOR score for language nahuatl: 0.1537084094388484
# Averaged Google Translate METEOR score for language nahuatl: 0.37397415558180974
#
#
# Averaged ChatGPT BLEU score for language quechua: 0.044483000192378164
# Averaged Google Translate BLEU score for language quechua: 0.05173093143883678
# Averaged ChatGPT METEOR score for language quechua: 0.15376728130646397
# Averaged Google Translate METEOR score for language quechua: 0.12990477029980818
#
#
# Averaged ChatGPT BLEU score for language wolof: 0.12215872273622862
# Averaged Google Translate BLEU score for language wolof: 0.37265824227799166
# Averaged ChatGPT METEOR score for language wolof: 0.3293560892782914
# Averaged Google Translate METEOR score for language wolof: 0.5031229846241754
